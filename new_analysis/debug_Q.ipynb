# %%
import numpy as np
import netCDF4 as nc

# %%
sample_data = nc.Dataset('/Users/jianda/Projects/experience_replay_data/2021_11_15.cam.h0.1999-04.nc')

# %%
Q = sample_data.variables['QL'][:]
print(Q.shape)
# Out:
# (1, 30, 96, 144)

# %%
Q = sample_data.variables["Q"][:]

# %%
print(Q.mean())
# Out:
# 0.0019615719

# %%
for key in sample_data.variables.keys():
    print(key)
# Out:
# lev
# hyam
# hybm
# ilev
# hyai
# hybi
# P0
# time
# date
# datesec
# lat
# lon
# slat
# slon
# w_stag
# time_bnds
# date_written
# time_written
# ntrm
# ntrn
# ntrk
# ndbase
# nsbase
# nbdate
# nbsec
# mdt
# nlon
# wnummax
# gw
# ndcur
# nscur
# co2vmr
# ch4vmr
# n2ovmr
# f11vmr
# f12vmr
# sol_tsi
# nsteph
# ABSORB
# AEROD_v
# ANRAIN
# ANSNOW
# AOD400
# AOD700
# AODABS
# AODDUST1
# AODDUST2
# AODDUST3
# AODMODE1
# AODMODE2
# AODMODE3
# AODVIS
# AQRAIN
# AQSNOW
# AQSO4_H2O2_EP
# AQSO4_O3_EP
# AREI
# AREL
# ATMEINT
# AWNC
# AWNI
# BFLX
# BURDEN1
# BURDEN2
# BURDEN3
# BURDENBC
# BURDENDUST
# BURDENPOM
# BURDENSEASALT
# BURDENSO4
# BURDENSOA
# CCN3
# CDNUMC
# CLDFSNOW
# CLDHGH
# CLDICE
# CLDLIQ
# CLDLOW
# CLDMED
# CLDTOT
# CLOUD
# CLOUDTOP
# CMFDQ
# CMFDQR
# CMFDT
# CMFMC
# CMFMCDZM
# CONCLD
# CRM_DD
# CRM_DU
# CRM_ED
# CRM_EU
# CRM_MD
# CRM_MU
# DCQ
# DMS
# DMSACHEM_EP
# DMSACT_EP
# DMSCONV_EP
# DMSEP
# DMSRENM_EP
# DMSSFACHDN_EP
# DMSSFACHEM_EP
# DMSSFACHQU_EP
# DMSSFACHUP_EP
# ...
