# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
Q_zonal = np.load("/Users/jiandachen/Projects/PaperWriting/replaybuffer/plot_data/Q_zonal_mean_era5.npy")*1000
T_zonal = np.load("/Users/jiandachen/Projects/PaperWriting/replaybuffer/plot_data/T_zonal_mean_era5.npy")
lev = np.array([  3.64346569,   7.59481965,  14.35663225,  24.61222   ,
                    38.26829977,  54.59547974,  72.01245055,  87.82123029,
                   103.31712663, 121.54724076, 142.99403876, 168.22507977,
                   197.9080867 , 232.82861896, 273.91081676, 322.24190235,
                   379.10090387, 445.9925741 , 524.68717471, 609.77869481,
                   691.38943031, 763.40448111, 820.85836865, 859.53476653,
                   887.02024892, 912.64454694, 936.19839847, 957.48547954,
                   976.32540739, 992.55609512])

# %%
print(T_zonal.shape)
# Out:
# (9, 72, 30, 96)

# %%
Q_zonal.shape
# Out:
# (9, 72, 30, 96)

# %%
expname = ["ERA5", "SPCAM", "CAM5", "Wang2022", "Wang2023(PhysC)", "Ours(Seed1117)", "Ours(Seed1)"]

# %%
# plot data with shape (30, 96), giving x ticks being lev, y ticks being np.arange(-90,90,96)
fig, axes = plt.subplots(3, 2, figsize=(15, 10))
# axes[0,0].set_title("SPCAM T Zonal Mean(K)")
# contour = axes[0,0].contourf(np.linspace(-90,90,96), lev, (T_zonal[0]).mean(axis=0))
# axes[0,0].set_xticks(np.arange(-90, 91, 30), [f"{lat}°{'S' if lat < 0 else 'N'}" for lat in range(-90, 91, 30)])
# axes[0,0].invert_yaxis()
# fig.colorbar(contour, ax=axes[0,0])
for i in range(3):
    for j in range(2):
        target_exp = i*2+j
        axes[i,j].set_title(f"{expname[target_exp]} T Zonal Mean (K)")
        contour = axes[i,j].contourf(np.linspace(-90,90,96), lev, (T_zonal[target_exp]).mean(axis=0))
        axes[i,j].set_xticks(np.arange(-90, 91, 30), [f"{lat}°{'S' if lat < 0 else 'N'}" for lat in range(-90, 91, 30)])
        axes[i,j].invert_yaxis()
        fig.colorbar(contour, ax=axes[i,j])

# %%
# plot data with shape (30, 96), giving x ticks being lev, y ticks being np.arange(-90,90,96)
fig, axes = plt.subplots(3, 2, figsize=(15, 10))
# axes[0,0].set_title("SPCAM T Zonal Mean(K)")
# contour = axes[0,0].contourf(np.linspace(-90,90,96), lev, (T_zonal[0]).mean(axis=0))
# axes[0,0].set_xticks(np.arange(-90, 91, 30), [f"{lat}°{'S' if lat < 0 else 'N'}" for lat in range(-90, 91, 30)])
# axes[0,0].invert_yaxis()
# fig.colorbar(contour, ax=axes[0,0])
# make axes[0,0] blank
# axes[0,0].boxplot([(T_zonal[i] - T_zonal[0]).mean(axis=0).flatten() for i in range(6)])
# axes[0,0].set_xticklabels(expname)
# axes[0,0].set_ylabel("Temperature Bias (K)")
for i in range(3):
    for j in range(2):
        target_exp = i*2+j+1
        print("target_exp:", target_exp, "i: ", i, "j: ", j)
        if target_exp <=2 :
            axes[i,j].set_title(f"{expname[target_exp]} Bias Versus ERA5 T Zonal Mean (K)\n Min/Max: {np.min(T_zonal[target_exp]-T_zonal[0]):.2f}/{np.max(T_zonal[target_exp]-T_zonal[0]):.2f}")
            contour = axes[i,j].contourf(np.linspace(-90,90,96), lev, (T_zonal[target_exp] - T_zonal[0]).mean(axis=0),np.arange(-10,23,1),cmap="RdBu_r", extend="both")
        else:
            axes[i,j].set_title(f"{expname[target_exp]} Bias Versus SPCAM T Zonal Mean (K)\n Min/Max: {np.min(T_zonal[target_exp]-T_zonal[0]):.2f}/{np.max(T_zonal[target_exp]-T_zonal[0]):.2f}")
            contour = axes[i,j].contourf(np.linspace(-90,90,96), lev, (T_zonal[target_exp] - T_zonal[1]).mean(axis=0),np.arange(-10,23,1),cmap="RdBu_r", extend="both")
        axes[i,j].set_xticks(np.arange(-90, 91, 30), [f"{lat}°{'S' if lat < 0 else 'N'}" for lat in range(-90, 91, 30)])
        axes[i,j].invert_yaxis()
        fig.colorbar(contour, ax=axes[i,j])
plt.tight_layout()
# Out:
# target_exp: 1 i:  0 j:  0
# target_exp: 2 i:  0 j:  1
# target_exp: 3 i:  1 j:  0
# target_exp: 4 i:  1 j:  1
# target_exp: 5 i:  2 j:  0
# target_exp: 6 i:  2 j:  1

# %%
# plot data with shape (30, 96), giving x ticks being lev, y ticks being np.arange(-90,90,96)
fig, axes = plt.subplots(3, 2, figsize=(15, 10))
# axes[0,0].set_title("SPCAM T Zonal Mean(K)")
# contour = axes[0,0].contourf(np.linspace(-90,90,96), lev, (T_zonal[0]).mean(axis=0))
# axes[0,0].set_xticks(np.arange(-90, 91, 30), [f"{lat}°{'S' if lat < 0 else 'N'}" for lat in range(-90, 91, 30)])
# axes[0,0].invert_yaxis()
# fig.colorbar(contour, ax=axes[0,0])
# make axes[0,0] blank
# axes[0,0].boxplot([(T_zonal[i] - T_zonal[0]).mean(axis=0).flatten() for i in range(6)])
# axes[0,0].set_xticklabels(expname)
# axes[0,0].set_ylabel("Temperature Bias (K)")
for i in range(3):
    for j in range(2):
        target_exp = i*2+j+1
        print("target_exp:", target_exp, "i: ", i, "j: ", j)
        if target_exp <=2 :
            axes[i,j].set_title(f"{expname[target_exp]} Bias Versus ERA5 T Zonal Mean (K)\n RMSE: {rmse(T_zonal[target_exp], T_zonal[0]):.2f}")
            contour = axes[i,j].contourf(np.linspace(-90,90,96), lev, (T_zonal[target_exp] - T_zonal[0]).mean(axis=0),np.arange(-10,23,1),cmap="RdBu_r", extend="both")
        else:
            axes[i,j].set_title(f"{expname[target_exp]} Bias Versus SPCAM T Zonal Mean (K)\n RMSE: {rmse(T_zonal[target_exp], T_zonal[1]):.2f}")
            contour = axes[i,j].contourf(np.linspace(-90,90,96), lev, (T_zonal[target_exp] - T_zonal[1]).mean(axis=0),np.arange(-10,23,1),cmap="RdBu_r", extend="both")
        axes[i,j].set_xticks(np.arange(-90, 91, 30), [f"{lat}°{'S' if lat < 0 else 'N'}" for lat in range(-90, 91, 30)])
        axes[i,j].invert_yaxis()
        fig.colorbar(contour, ax=axes[i,j])
plt.tight_layout()
# Out:
# target_exp: 1 i:  0 j:  0
# target_exp: 2 i:  0 j:  1
# target_exp: 3 i:  1 j:  0
# target_exp: 4 i:  1 j:  1
# target_exp: 5 i:  2 j:  0
# target_exp: 6 i:  2 j:  1

# %%
# plot data with shape (30, 96), giving x ticks being lev, y ticks being np.arange(-90,90,96)
fig, axes = plt.subplots(3, 2, figsize=(15, 12))
# axes[0,0].set_title("SPCAM T Zonal Mean(K)")
# contour = axes[0,0].contourf(np.linspace(-90,90,96), lev, (T_zonal[0]).mean(axis=0))
# axes[0,0].set_xticks(np.arange(-90, 91, 30), [f"{lat}°{'S' if lat < 0 else 'N'}" for lat in range(-90, 91, 30)])
# axes[0,0].invert_yaxis()
# fig.colorbar(contour, ax=axes[0,0])
# make axes[0,0] blank
# axes[0,0].boxplot([(T_zonal[i] - T_zonal[0]).mean(axis=0).flatten() for i in range(6)])
# axes[0,0].set_xticklabels(expname)
# axes[0,0].set_ylabel("Temperature Bias (K)")
for i in range(3):
    for j in range(2):
        target_exp = i*2+j+1
        print("target_exp:", target_exp, "i: ", i, "j: ", j)
        axes[i,j].set_title(f"{expname[target_exp]} Bias Versus ERA5 T Zonal Mean (K)\n Min/Max: {np.min(T_zonal[target_exp]-T_zonal[0]):.2f}/{np.max(T_zonal[target_exp]-T_zonal[0]):.2f}")
        contour = axes[i,j].contourf(np.linspace(-90,90,96), lev, (T_zonal[target_exp] - T_zonal[0]).mean(axis=0),np.arange(-10,23,1),cmap="RdBu_r", extend="both")
        axes[i,j].set_xticks(np.arange(-90, 91, 30), [f"{lat}°{'S' if lat < 0 else 'N'}" for lat in range(-90, 91, 30)])
        axes[i,j].invert_yaxis()
        fig.colorbar(contour, ax=axes[i,j])
plt.tight_layout()
# Out:
# target_exp: 1 i:  0 j:  0
# target_exp: 2 i:  0 j:  1
# target_exp: 3 i:  1 j:  0
# target_exp: 4 i:  1 j:  1
# target_exp: 5 i:  2 j:  0
# target_exp: 6 i:  2 j:  1

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

# %%
# plot data with shape (30, 96), giving x ticks being lev, y ticks being np.arange(-90,90,96)
fig, axes = plt.subplots(3, 2, figsize=(15, 12))
# axes[0,0].set_title("SPCAM T Zonal Mean(K)")
# contour = axes[0,0].contourf(np.linspace(-90,90,96), lev, (T_zonal[0]).mean(axis=0))
# axes[0,0].set_xticks(np.arange(-90, 91, 30), [f"{lat}°{'S' if lat < 0 else 'N'}" for lat in range(-90, 91, 30)])
# axes[0,0].invert_yaxis()
# fig.colorbar(contour, ax=axes[0,0])
# make axes[0,0] blank
# axes[0,0].boxplot([(T_zonal[i] - T_zonal[0]).mean(axis=0).flatten() for i in range(6)])
# axes[0,0].set_xticklabels(expname)
# axes[0,0].set_ylabel("Temperature Bias (K)")
for i in range(3):
    for j in range(2):
        target_exp = i*2+j+1
        print("target_exp:", target_exp, "i: ", i, "j: ", j)
        axes[i,j].set_title(f"{expname[target_exp]} Bias Versus ERA5 T Zonal Mean (K)\n RMSE: {rmse(T_zonal[target_exp],T_zonal[0]):.2f} K")
        contour = axes[i,j].contourf(np.linspace(-90,90,96), lev, (T_zonal[target_exp] - T_zonal[0]).mean(axis=0),np.arange(-10,11,1),cmap="RdBu_r", extend="both")
        axes[i,j].set_xticks(np.arange(-90, 91, 30), [f"{lat}°{'S' if lat < 0 else 'N'}" for lat in range(-90, 91, 30)])
        axes[i,j].invert_yaxis()
        fig.colorbar(contour, ax=axes[i,j])
plt.tight_layout()
# Out:
# target_exp: 1 i:  0 j:  0
# target_exp: 2 i:  0 j:  1
# target_exp: 3 i:  1 j:  0
# target_exp: 4 i:  1 j:  1
# target_exp: 5 i:  2 j:  0
# target_exp: 6 i:  2 j:  1

# %%
# plot data with shape (30, 96), giving x ticks being lev, y ticks being np.arange(-90,90,96)
fig, axes = plt.subplots(3, 2, figsize=(15, 10))
# axes[0,0].set_title("SPCAM T Zonal Mean(K)")
# contour = axes[0,0].contourf(np.linspace(-90,90,96), lev, (T_zonal[0]).mean(axis=0))
# axes[0,0].set_xticks(np.arange(-90, 91, 30), [f"{lat}°{'S' if lat < 0 else 'N'}" for lat in range(-90, 91, 30)])
# axes[0,0].invert_yaxis()
# fig.colorbar(contour, ax=axes[0,0])
for i in range(3):
    for j in range(2):
        target_exp = i*2+j
        axes[i,j].set_title(f"{expname[target_exp]} Q Zonal Mean (g/Kg)")
        contour = axes[i,j].contourf(np.linspace(-90,90,96), lev, (Q_zonal[target_exp]).mean(axis=0))
        axes[i,j].set_xticks(np.arange(-90, 91, 30), [f"{lat}°{'S' if lat < 0 else 'N'}" for lat in range(-90, 91, 30)])
        axes[i,j].invert_yaxis()
        fig.colorbar(contour, ax=axes[i,j])

# %%
# plot data with shape (30, 96), giving x ticks being lev, y ticks being np.arange(-90,90,96)
fig, axes = plt.subplots(3, 2, figsize=(15, 10))
# axes[0,0].set_title("SPCAM T Zonal Mean(K)")
# contour = axes[0,0].contourf(np.linspace(-90,90,96), lev, (T_zonal[0]).mean(axis=0))
# axes[0,0].set_xticks(np.arange(-90, 91, 30), [f"{lat}°{'S' if lat < 0 else 'N'}" for lat in range(-90, 91, 30)])
# axes[0,0].invert_yaxis()
# fig.colorbar(contour, ax=axes[0,0])
# make axes[0,0] blank
# axes[0,0].boxplot([(T_zonal[i] - T_zonal[0]).mean(axis=0).flatten() for i in range(6)])
# axes[0,0].set_xticklabels(expname)
# axes[0,0].set_ylabel("Temperature Bias (K)")
for i in range(3):
    for j in range(2):
        target_exp = i*2+j+1
        print("target_exp:", target_exp, "i: ", i, "j: ", j)
        if target_exp <=2 :
            axes[i,j].set_title(f"{expname[target_exp]} Bias Versus ERA5 Q Zonal Mean (K)\n Min/Max: {np.min(Q_zonal[target_exp]-Q_zonal[0]):.2f}/{np.max(Q_zonal[target_exp]-Q_zonal[0]):.2f}")
            contour = axes[i,j].contourf(np.linspace(-90,90,96), lev, (Q_zonal[target_exp] - Q_zonal[0]).mean(axis=0),np.arange(-1,1.1,0.1),cmap="RdBu_r", extend="both")
        else:
            axes[i,j].set_title(f"{expname[target_exp]} Bias Versus SPCAM Q Zonal Mean (K)\n Min/Max: {np.min(Q_zonal[target_exp]-Q_zonal[0]):.2f}/{np.max(Q_zonal[target_exp]-Q_zonal[0]):.2f}")
            contour = axes[i,j].contourf(np.linspace(-90,90,96), lev, (Q_zonal[target_exp] - Q_zonal[1]).mean(axis=0),np.arange(-1,1.1,0.1),cmap="RdBu_r", extend="both")
        axes[i,j].set_xticks(np.arange(-90, 91, 30), [f"{lat}°{'S' if lat < 0 else 'N'}" for lat in range(-90, 91, 30)])
        axes[i,j].invert_yaxis()
        fig.colorbar(contour, ax=axes[i,j])
plt.tight_layout()
# Out:
# target_exp: 1 i:  0 j:  0
# target_exp: 2 i:  0 j:  1
# target_exp: 3 i:  1 j:  0
# target_exp: 4 i:  1 j:  1
# target_exp: 5 i:  2 j:  0
# target_exp: 6 i:  2 j:  1

# %%
T_zonal.shape
# Out:
# (9, 72, 30, 96)

# %%
# plot data with shape (30, 96), giving x ticks being lev, y ticks being np.arange(-90,90,96)
fig, axes = plt.subplots(3, 2, figsize=(15, 10))
# axes[0,0].set_title("SPCAM T Zonal Mean(K)")
# contour = axes[0,0].contourf(np.linspace(-90,90,96), lev, (T_zonal[0]).mean(axis=0))
# axes[0,0].set_xticks(np.arange(-90, 91, 30), [f"{lat}°{'S' if lat < 0 else 'N'}" for lat in range(-90, 91, 30)])
# axes[0,0].invert_yaxis()
# fig.colorbar(contour, ax=axes[0,0])
# make axes[0,0] blank
axes[0,0].boxplot([(T_zonal[i] - T_zonal[0]).mean(axis=0).flatten() for i in range(6)])
axes[0,0].set_xticklabels(expname)
axes[0,0].set_ylabel("Temperature Bias (K)")
for i in range(3):
    for j in range(2):
        if i == 0 and j == 0:
            continue
        target_exp = i*2+j
        axes[i,j].set_title(f"{expname[target_exp]} Bias Versus SPCAM T Zonal Mean (K)\n Min/Max: {np.min(T_zonal[target_exp]-T_zonal[0]):.2f}/{np.max(T_zonal[target_exp]-T_zonal[0]):.2f}")
        contour = axes[i,j].contourf(np.linspace(-90,90,96), lev, (T_zonal[target_exp] - T_zonal[0]).mean(axis=0),np.arange(-8,23,1),cmap="RdBu_r")
        axes[i,j].set_xticks(np.arange(-90, 91, 30), [f"{lat}°{'S' if lat < 0 else 'N'}" for lat in range(-90, 91, 30)])
        axes[i,j].invert_yaxis()
        fig.colorbar(contour, ax=axes[i,j])
plt.tight_layout()

# %%
# plot data with shape (30, 96), giving x ticks being lev, y ticks being np.arange(-90,90,96)
fig, axes = plt.subplots(3, 2, figsize=(15, 10))
# axes[0,0].set_title("SPCAM T Zonal Mean(K)")
# contour = axes[0,0].contourf(np.linspace(-90,90,96), lev, (T_zonal[0]).mean(axis=0))
# axes[0,0].set_xticks(np.arange(-90, 91, 30), [f"{lat}°{'S' if lat < 0 else 'N'}" for lat in range(-90, 91, 30)])
# axes[0,0].invert_yaxis()
# fig.colorbar(contour, ax=axes[0,0])
# make axes[0,0] blank
axes[0,0].boxplot([(Q_zonal[i] - Q_zonal[0]).mean(axis=0).flatten() for i in range(6)])
axes[0,0].set_xticklabels(expname)
axes[0,0].set_ylabel("Moisture Bias (g/Kg)")
for i in range(3):
    for j in range(2):
        if i == 0 and j == 0:
            continue
        target_exp = i*2+j
        axes[i,j].set_title(f"{expname[target_exp]} Bias Versus SPCAM Q Zonal Mean (k/kg)\n Min/Max: {np.min(Q_zonal[target_exp]-Q_zonal[0]):.2f}/{np.max(Q_zonal[target_exp]-Q_zonal[0]):.2f}")
        contour = axes[i,j].contourf(np.linspace(-90,90,96), lev, (Q_zonal[target_exp] - Q_zonal[0]).mean(axis=0),np.arange(-0.8,1.1,0.1),cmap="RdBu_r")
        axes[i,j].set_xticks(np.arange(-90, 91, 30), [f"{lat}°{'S' if lat < 0 else 'N'}" for lat in range(-90, 91, 30)])
        axes[i,j].invert_yaxis()
        fig.colorbar(contour, ax=axes[i,j])
plt.tight_layout()
